# %%
# !pip install nltk
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# !pip install pyresparser
# !pip install spacy
# !python -m nltk.downloader stopwords
# Out:
# Collecting nltk
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting joblib
#   Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.10.31-cp36-cp36m-win_amd64.whl (279 kB)
# Collecting click
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: colorama in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from click->nltk) (0.4.5)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Installing collected packages: zipp, typing-extensions, importlib-resources, importlib-metadata, tqdm, regex, joblib, click, nltk
# Successfully installed click-8.0.4 importlib-metadata-4.8.3 importlib-resources-5.4.0 joblib-1.1.1 nltk-3.6.7 regex-2022.10.31 tqdm-4.64.1 typing-extensions-4.1.1 zipp-3.6.0
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp36-cp36m-win_amd64.whl (9.5 MB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp36-cp36m-win_amd64.whl (36 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.9-cp36-cp36m-win_amd64.whl (7.0 MB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy==2.3.5) (4.64.1)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.6-cp36-cp36m-win_amd64.whl (910 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp36-cp36m-win_amd64.whl (207 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Collecting requests<3.0.0,>=2.13.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp36-cp36m-win_amd64.whl (111 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting numpy>=1.15.0
#   Downloading numpy-1.19.5-cp36-cp36m-win_amd64.whl (13.2 MB)
# Requirement already satisfied: setuptools in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy==2.3.5) (39.0.1)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp36-cp36m-win_amd64.whl (21 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (3.6.0)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: colorama in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==2.3.5) (0.4.5)
# Requirement already satisfied: importlib-resources in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==2.3.5) (5.4.0)
# Installing collected packages: numpy, murmurhash, cymem, wasabi, urllib3, srsly, preshed, plac, idna, charset-normalizer, certifi, catalogue, blis, thinc, requests, spacy
# Successfully installed blis-0.7.9 catalogue-1.0.2 certifi-2022.12.7 charset-normalizer-2.0.12 cymem-2.0.7 idna-3.4 murmurhash-1.0.9 numpy-1.19.5 plac-1.1.3 preshed-3.0.8 requests-2.27.1 spacy-2.3.5 srsly-1.0.6 thinc-7.4.6 urllib3-1.26.14 wasabi-0.10.1
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from en-core-web-sm==2.3.1) (2.3.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.0.8)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (7.4.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.2)
# Requirement already satisfied: setuptools in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (39.0.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (4.64.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.7.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.27.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.19.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.6)
# Requirement already satisfied: zipp>=0.5 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.26.14)
# Requirement already satisfied: colorama in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.4.5)
# Requirement already satisfied: importlib-resources in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (5.4.0)
# Using legacy 'setup.py install' for en-core-web-sm, since package 'wheel' is not installed.
# Installing collected packages: en-core-web-sm
#     Running setup.py install for en-core-web-sm: started
#     Running setup.py install for en-core-web-sm: finished with status 'done'
# Successfully installed en-core-web-sm-2.3.1
# Collecting pyresparser
#   Downloading pyresparser-1.0.6-py3-none-any.whl (4.2 MB)
# Requirement already satisfied: spacy>=2.1.4 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (2.3.5)
# Collecting jsonschema>=3.0.1
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Requirement already satisfied: wasabi>=0.2.2 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (0.10.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (2.8.2)
# Requirement already satisfied: certifi>=2019.6.16 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (2022.12.7)
# Collecting pytz>=2019.1
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
# Collecting sortedcontainers>=2.1.0
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting pdfminer.six>=20181108
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: urllib3>=1.25.3 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (1.26.14)
# Requirement already satisfied: nltk>=3.4.3 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (3.6.7)
# Requirement already satisfied: numpy>=1.16.4 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (1.19.5)
# Requirement already satisfied: six>=1.12.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (1.16.0)
# Requirement already satisfied: blis>=0.2.4 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (0.7.9)
# Requirement already satisfied: srsly>=0.0.7 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (1.0.6)
# Collecting pycryptodome>=3.8.2
#   Downloading pycryptodome-3.17-cp35-abi3-win_amd64.whl (1.7 MB)
# Collecting chardet>=3.0.4
#   Downloading chardet-5.0.0-py3-none-any.whl (193 kB)
# Collecting docx2txt>=0.7
#   Using cached docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: preshed>=2.0.1 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (3.0.8)
# Collecting attrs>=19.1.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
# Requirement already satisfied: thinc>=7.0.4 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (7.4.6)
# Requirement already satisfied: requests>=2.22.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (2.27.1)
# Collecting pyrsistent>=0.15.2
#   Downloading pyrsistent-0.18.0-cp36-cp36m-win_amd64.whl (62 kB)
# Requirement already satisfied: idna>=2.8 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (3.4)
# Collecting pandas>=0.24.2
#   Downloading pandas-1.1.5-cp36-cp36m-win_amd64.whl (8.7 MB)
# Requirement already satisfied: tqdm>=4.32.2 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (4.64.1)
# Requirement already satisfied: cymem>=2.0.2 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pyresparser) (2.0.7)
# Requirement already satisfied: importlib-metadata in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from jsonschema>=3.0.1->pyresparser) (4.8.3)
# Requirement already satisfied: setuptools in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from jsonschema>=3.0.1->pyresparser) (39.0.1)
# Requirement already satisfied: joblib in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from nltk>=3.4.3->pyresparser) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from nltk>=3.4.3->pyresparser) (2022.10.31)
# Requirement already satisfied: click in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from nltk>=3.4.3->pyresparser) (8.0.4)
# Collecting cryptography>=36.0.0
#   Downloading cryptography-39.0.2-cp36-abi3-win_amd64.whl (2.5 MB)
# Requirement already satisfied: typing-extensions in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pdfminer.six>=20181108->pyresparser) (4.1.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from pdfminer.six>=20181108->pyresparser) (2.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from preshed>=2.0.1->pyresparser) (1.0.9)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy>=2.1.4->pyresparser) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from spacy>=2.1.4->pyresparser) (1.0.2)
# Requirement already satisfied: importlib-resources in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from tqdm>=4.32.2->pyresparser) (5.4.0)
# Requirement already satisfied: colorama in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from tqdm>=4.32.2->pyresparser) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in d:\sfu assignments spring 2023\cmpt_733\omnibot\.venv\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.1.4->pyresparser) (3.6.0)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp36-cp36m-win_amd64.whl (187 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Using legacy 'setup.py install' for docx2txt, since package 'wheel' is not installed.
# Installing collected packages: pycparser, cffi, pytz, pyrsistent, cryptography, attrs, sortedcontainers, pycryptodome, pdfminer.six, pandas, jsonschema, docx2txt, chardet, pyresparser
#     Running setup.py install for docx2txt: started
#     Running setup.py install for docx2txt: finished with status 'done'
# Successfully installed attrs-22.2.0 cffi-1.15.1 chardet-5.0.0 cryptography-39.0.2 docx2txt-0.8 jsonschema-3.2.0 pandas-1.1.5 pdfminer.six-20221105 pycparser-2.21 pycryptodome-3.17 pyresparser-1.0.6 pyrsistent-0.18.0 pytz-2022.7.1 sortedcontainers-2.4.0

# %%
from pyresparser import ResumeParser
data = ResumeParser('sample_resume.pdf').get_extracted_data()

# %%
for item in data:
    print(f'{item}:{data[item]}')
# Out:
# name:RISHABH JAIN
# email:rishabhjain7b@gmail.com
# mobile_number:9198102038
# skills:['Interactive', 'Ubuntu', 'Technical', 'Os', 'System', 'Circuits', 'Python', 'Protocols', 'Design', 'Electronics', 'Training', 'C++', 'Scripting', 'Linux', 'International', 'C', 'Shell', 'Sdx', 'Communication']
# college_name:None
# degree:['Bachelor of Technology (Electronics\n& Communication)']
# designation:['SOFTWARE ENGINEER']
# experience:['End VLSI domain using tcl/shell, Verilog and System Verilog.', 'AISSCE (CLASS XII)', 'Bal Bharati Public School', '(cid:17) 2014', '• 89.6%', '‰ Brij Vihar, U.P.', 'CLASS X', 'Bal Bharati Public School', '(cid:17) 2012', '‰ Brij Vihar, U.P.', '• CGPA: 9.4/10']
# company_names:['DKOP Labs Pvt. Ltd.', 'Mentor Graphics Pvt. Ltd.']
# no_of_pages:1
# total_experience:0.0
